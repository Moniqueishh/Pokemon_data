# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:

import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "http://ergast.com/api/f1/2008/5/driverStandings.json" #Need to have .json

# %%
# response object
response = requests.get(url)
print(response) #checking if the connection was successful
# Out:
# <Response [200]>

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
data = response.json()
data
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.5',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
# We only want the Driver Standings
x = data["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]

# %%
def get_top(data):
    new_data = []
    for d in data:
        driver = {} # we are going to put each driver in their own dictionary 
        d_name = d["Driver"]["familyName"]
        
        driver[d_name] = {
            "first_name": d["Driver"]["givenName"],
            "last_name" : d["Driver"]["familyName"],
            "position" : d["position"],
            "nationality": d["Driver"]["nationality"],
            "team": d["Constructors"][0]["constructorId"],            
            
        }
        
        new_data.append(driver)
    return new_data

# %%
get_top(x)
# Out:
# [{'Räikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'position': '1',
#    'nationality': 'Finnish',
#    'team': 'ferrari'}},
#  {'Massa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'position': '2',
#    'nationality': 'Brazilian',
#    'team': 'ferrari'}},
#  {'Hamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'position': '3',
#    'nationality': 'British',
#    'team': 'mclaren'}},
#  {'Kubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'position': '4',
#    'nationality': 'Polish',
#    'team': 'bmw_sauber'}},
#  {'Heidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'position': '5',
#    'nationality': 'German',
#    'team': 'bmw_sauber'}},
#  {'Kovalainen': {'first_name': 'Heikki',
#    'last_name': 'Kovalainen',
#    'position': '6',
#    'nationality': 'Finnish',
#    'team': 'mclaren'}},
#  {'Webber': {'first_name': 'Mark',
#    'last_name': 'Webber',
#    'position': '7',
# ...

# %%
# http://ergast.com/api/f1/2008/5/results.json

# %%
def driver_results(year,round):
    url = f"http://ergast.com/api/f1/{year}/{round}/results.json" 
    response = requests.get(url)
    data = response.json()["MRData"]["RaceTable"]["Races"][0]["Results"]
#     print(data)
    for d in data:
        print(f"Finishing in po {d['position']} is {d['Driver']['driverId']}")

# %%
driver_results(2013, 7)
# Out:
# Finishing in po 1 is vettel
# Finishing in po 2 is alonso
# Finishing in po 3 is hamilton
# Finishing in po 4 is webber
# Finishing in po 5 is rosberg
# Finishing in po 6 is vergne
# Finishing in po 7 is resta
# Finishing in po 8 is massa
# Finishing in po 9 is raikkonen
# Finishing in po 10 is sutil
# Finishing in po 11 is perez
# Finishing in po 12 is button
# Finishing in po 13 is grosjean
# Finishing in po 14 is bottas
# Finishing in po 15 is ricciardo
# Finishing in po 16 is maldonado
# Finishing in po 17 is jules_bianchi
# Finishing in po 18 is pic
# Finishing in po 19 is chilton
# Finishing in po 20 is gutierrez
# Finishing in po 21 is hulkenberg
# Finishing in po 22 is garde

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', attack base_state, hp base_stat, defense base_stat

# %%
import requests, json

# %%
url = "https://pokeapi.co/api/v2/pokemon"
url2 = ""
# response object
response = requests.get(url)
print(response) #checking if the connection was successful
# Out:
# <Response [200]>

# %%
response.ok
# Out:
# True

# %%
response.json()
# Out:
# {'count': 1281,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
# ...

# %%
type(response.json())
data = response.json()
data
# Out:
# {'count': 1281,
#  'next': 'https://pokeapi.co/api/v2/pokemon?offset=20&limit=20',
#  'previous': None,
#  'results': [{'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon/1/'},
#   {'name': 'ivysaur', 'url': 'https://pokeapi.co/api/v2/pokemon/2/'},
#   {'name': 'venusaur', 'url': 'https://pokeapi.co/api/v2/pokemon/3/'},
#   {'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon/4/'},
#   {'name': 'charmeleon', 'url': 'https://pokeapi.co/api/v2/pokemon/5/'},
#   {'name': 'charizard', 'url': 'https://pokeapi.co/api/v2/pokemon/6/'},
#   {'name': 'squirtle', 'url': 'https://pokeapi.co/api/v2/pokemon/7/'},
#   {'name': 'wartortle', 'url': 'https://pokeapi.co/api/v2/pokemon/8/'},
#   {'name': 'blastoise', 'url': 'https://pokeapi.co/api/v2/pokemon/9/'},
#   {'name': 'caterpie', 'url': 'https://pokeapi.co/api/v2/pokemon/10/'},
#   {'name': 'metapod', 'url': 'https://pokeapi.co/api/v2/pokemon/11/'},
# ...

# %%
# Get the pokemons: name, atleast one ability's name, base_experience, 
# and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', 
# attack base_state, hp base_stat, defense base_stat
x = data["results"]
# x = data["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]

# %%
# def pokemon(data):
#     new_data = []
#     for p in data:
#         poke = {} # we are going to put each pokemon in their own dictionary 
#         p_name = p["name"]
        
#         poke[p_name] = {
#             "name": p["name"],
#             "ability" : p["url"]#["abilities"][0]#["name"]
# #             "base experience" : p["base_experience"],
# #             "sprite url": p["Driver"]["nationality"],
# #             "attack base stat": p["Constructors"][0]["constructorId"],
# #             "hp base stat" : p["stats"]["base_stat"],
# #             "defense base_stat" : p["ability"],
            
#         }
        
#         new_data.append(poke)
#     return new_data

# def get_top(data):
#     new_data = []
#     for d in data:
#         driver = {} # we are going to put each driver in their own dictionary 
#         d_name = d["Driver"]["familyName"]
        
#         driver[d_name] = {
#             "first_name": d["Driver"]["givenName"],
#             "last_name" : d["Driver"]["familyName"],
#             "position" : d["position"],
#             "nationality": d["Driver"]["nationality"],
#             "team": d["Constructors"][0]["constructorId"],            
            
#         }
        
#         new_data.append(driver)
#     return new_data

# %%
pokemon(x)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
# ...

# %%
# def driver_results(year,round):
#     url = f"http://ergast.com/api/f1/{year}/{round}/results.json" 
#     response = requests.get(url)
#     data = response.json()["MRData"]["RaceTable"]["Races"][0]["Results"]
# #     print(data)
#     for d in data:
#         print(f"Finishing in po {d['position']} is {d['Driver']['driverId']}")

def pokemon(name):
    url = f"https://pokeapi.co/api/v2/pokemon/{name}" 
    response = requests.get(url)
    data = response.json()
#     name = input("Please enter the Pokemon you want to view: ")
    print(f"Name: {data['name']}\nAbility: {data['abilities'][0]['ability']['name']}\nBase experience: {data['base_experience']}\nFront Shiny: {data['sprites']['front_shiny']}\nHP- base stat: {data['stats'][0]['base_stat']}\nAttack- base stat: {data['stats'][1]['base_stat']}\nDefense- base stat: {data['stats'][2]['base_stat']}" )
# HP- base state: {data['stats'][0]['base_stat']} 

pokemon("ditto")
# Out:
# Name: ditto
# Ability: limber
# Base experience: 101
# Front Shiny: https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/shiny/132.png
# HP- base stat: 48
# Attack- base stat: 48
# Defense- base stat: 48

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/g6/6_fkpzdx0qzg859w55t36_h80000gq/T/ipykernel_76742/1892028495.py in <module>
# ----> 1 pokemon(name)
#
# NameError: name 'name' is not defined

# %%
# Get the pokemons: name, atleast one ability's name, base_experience, 
# and the URL for its sprite (an image that shows up on screen) for the 'front_shiny', 
# attack base_state, hp base_stat, defense base_stat
